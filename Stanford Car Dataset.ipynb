# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importing helpful libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from PIL import Image
import os
print(os.listdir("/Users/milindpathiyal/Desktop/stanford-car-dataset-by-classes-folder/"))
# Out:
# ['.DS_Store', 'car_data', 'anno_test.csv', 'names.csv', 'anno_train.csv']

# %%
os.listdir("/Users/milindpathiyal/Desktop/stanford-car-dataset-by-classes-folder/car_data/car_data")
# Out:
# ['.DS_Store', 'test', 'train']

# %%
#Making seperate variables for train and test directories
train_dir = "/Users/milindpathiyal/Desktop/stanford-car-dataset-by-classes-folder/car_data/car_data/train"
test_dir = "/Users/milindpathiyal/Desktop/stanford-car-dataset-by-classes-folder/car_data/car_data/test"

# %%
#Dictionary that has name of car class as key and image name as its values
car_names_train = {}

for i in os.listdir(train_dir):
    car_names_train[i] = os.listdir(train_dir + '/' + i)

# %%
#Code to create two lists for class name and image directories corresponding to it
car_images_ls = []
car_names_ls = []
car_classes = []
car_directories = []

for i in car_names_train:
    car_classes.append(i)

for i,j in enumerate(car_names_train.values()):
    for img in j:
        car_images_ls.append(img)
        car_names_ls.append(car_classes[i])
        
for i in range(len(car_names_ls)):
    car_directories.append(train_dir + '/' + car_names_ls[i] + '/' + car_images_ls[i])

# %%
#Sample image to check the consistency of the two lists
plt.imshow(Image.open(car_directories[1000]))
plt.title(car_names_ls[1000])
# Out:
# Text(0.5, 1.0, 'Acura TSX Sedan 2012')

# %%
#Creating a data frame from the above two lists
df = pd.DataFrame(data = [car_directories, car_names_ls], index = ["Directories", "Car Class"]).T
df.head()
df.to_csv('car_names_directories.csv', index = False)

# %%
#Importing various modules from the Keras Library that are used in Deep Learning
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import densenet
from keras.models import Sequential, Model, load_model
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, Callback
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
#Pre-Defining some hyper-parameters
img_width, img_height = 256, 256
nb_train_samples = 8144
nb_validation_samples = 8041
epochs = 10
steps_per_epoch = 256
batch_size = 64
n_classes = 196

# %%
#Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./ 255,
    zoom_range=0.2,
    rotation_range = 8,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 8144 images belonging to 196 classes.
# Found 8041 images belonging to 196 classes.

# %%
#Creating the Convolution Neural Network
cnn = Sequential()
cnn.add(Conv2D(filters = 16, kernel_size = (5,5), padding = 'same', activation = 'relu', input_shape = (256,256,3)))
cnn.add(MaxPooling2D(pool_size = (2,2)))
cnn.add(Dropout(0.22))
cnn.add(Conv2D(filters = 32, kernel_size = (5,5), padding = 'same', activation = 'relu', input_shape = (256,256,3)))
cnn.add(MaxPooling2D(pool_size = (2,2)))
cnn.add(Dropout(0.22))
cnn.add(Conv2D(filters = 64, kernel_size = (4,4), padding = 'same', activation = 'relu', input_shape = (256,256,3)))
cnn.add(MaxPooling2D(pool_size = (2,2)))
cnn.add(Dropout(0.2))
cnn.add(Conv2D(filters = 96, kernel_size = (3,3), padding = 'same', activation = 'relu', input_shape = (256,256,3)))
cnn.add(MaxPooling2D(pool_size = (2,2)))
cnn.add(Flatten())
cnn.add(Dropout(0.18))
cnn.add(Dense(512, activation = 'relu'))
cnn.add(Dense(512, activation = 'relu'))
cnn.add(Dense(196, activation = 'sigmoid'))
cnn.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
#Let's take a look at the CNN we created
cnn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 256, 256, 16)      1216
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 128, 128, 16)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 128, 32)      12832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 64)        32832
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 96)        55392
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 96)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 24576)             0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 24576)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               12583424
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_3 (Dense)              (None, 196)               100548
# =================================================================
# Total params: 13,048,900
# Trainable params: 13,048,900
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Training begins here
model_history = cnn.fit_generator(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    steps_per_epoch = steps_per_epoch,
    validation_steps = nb_validation_samples // batch_size)

cnn.save_weights('stanford_cars_folder_cnn_weights.h5')
# Out:
# Epoch 1/10
# 256/256 [==============================] - 1549s 6s/step - loss: 5.2813 - accuracy: 0.0071 - val_loss: 5.2762 - val_accuracy: 0.0085
# Epoch 2/10
# 256/256 [==============================] - 1561s 6s/step - loss: 5.2769 - accuracy: 0.0083 - val_loss: 5.2812 - val_accuracy: 0.0084
# Epoch 3/10
# 256/256 [==============================] - 1477s 6s/step - loss: 5.2763 - accuracy: 0.0083 - val_loss: 5.2672 - val_accuracy: 0.0081
# Epoch 4/10
# 256/256 [==============================] - 1503s 6s/step - loss: 5.2748 - accuracy: 0.0083 - val_loss: 5.2661 - val_accuracy: 0.0089
# Epoch 5/10
# 256/256 [==============================] - 1485s 6s/step - loss: 5.2743 - accuracy: 0.0083 - val_loss: 5.2890 - val_accuracy: 0.0085
# Epoch 6/10
# 256/256 [==============================] - 1469s 6s/step - loss: 5.2748 - accuracy: 0.0083 - val_loss: 5.2676 - val_accuracy: 0.0081
# Epoch 7/10
# 256/256 [==============================] - 1469s 6s/step - loss: 5.2744 - accuracy: 0.0083 - val_loss: 5.2836 - val_accuracy: 0.0088
# Epoch 8/10
# 256/256 [==============================] - 1467s 6s/step - loss: 5.2741 - accuracy: 0.0083 - val_loss: 5.2672 - val_accuracy: 0.0083
# Epoch 9/10
# 256/256 [==============================] - 1474s 6s/step - loss: 5.2740 - accuracy: 0.0083 - val_loss: 5.2529 - val_accuracy: 0.0084
# Epoch 10/10
# 256/256 [==============================] - 1465s 6s/step - loss: 5.2739 - accuracy: 0.0083 - val_loss: 5.2643 - val_accuracy: 0.0081

# %%
#Visualization of how validation and training set performs per epoch
plt.figure(0, figsize = (5,5))
plt.plot(model_history.history['accuracy'],'orange')
plt.plot(model_history.history['val_accuracy'],'blue')
plt.legend(['Train-Accuracy','Val-Accuracy'])
_ = plt.title('Train vs Val Accuracy')
_ = plt.xlabel('Epochs')
_ = plt.ylabel('Accuracy')

plt.figure(1, figsize = (5,5))
plt.plot(model_history.history['loss'],'orange')
plt.plot(model_history.history['val_loss'],'blue')
plt.legend(['train','validation'])
_ = plt.xlabel("Num of Epochs")
_ = plt.ylabel("Loss")
_ = plt.title("Training Loss vs Validation Loss")

# %%
#"""TO OVERFIT THE MODEL"""
#As there is insufficient images per class (40-45 images per set for 196 classes) to get satisfactory
#results, I overfitted the model to perform best on the training set
model_history = cnn.fit_generator(
    train_generator,
    epochs=epochs + 20,
    validation_data=validation_generator,
    steps_per_epoch = steps_per_epoch,
    validation_steps = nb_validation_samples // batch_size)

cnn.save_weights('stanford_cars_folder_cnn_weights_OVERFITTED.h5')
# Out:
# Epoch 1/30
# 256/256 [==============================] - 1780s 7s/step - loss: 5.2740 - accuracy: 0.0083 - val_loss: 5.2487 - val_accuracy: 0.0085
# Epoch 2/30
# 256/256 [==============================] - 1668s 7s/step - loss: 5.2739 - accuracy: 0.0083 - val_loss: 5.2763 - val_accuracy: 0.0085
# Epoch 3/30
# 256/256 [==============================] - 1631s 6s/step - loss: 5.2738 - accuracy: 0.0083 - val_loss: 5.2561 - val_accuracy: 0.0084
# Epoch 4/30
# 256/256 [==============================] - 1466s 6s/step - loss: 5.2739 - accuracy: 0.0083 - val_loss: 5.2630 - val_accuracy: 0.0084
# Epoch 5/30
# 256/256 [==============================] - 1797s 7s/step - loss: 5.2738 - accuracy: 0.0083 - val_loss: 5.2470 - val_accuracy: 0.0086
# Epoch 6/30
# 256/256 [==============================] - 1617s 6s/step - loss: 5.2738 - accuracy: 0.0083 - val_loss: 5.2797 - val_accuracy: 0.0080
# Epoch 7/30
# 256/256 [==============================] - 1619s 6s/step - loss: 5.2737 - accuracy: 0.0083 - val_loss: 5.2663 - val_accuracy: 0.0086
# Epoch 8/30
# 256/256 [==============================] - 1467s 6s/step - loss: 5.2736 - accuracy: 0.0083 - val_loss: 5.2619 - val_accuracy: 0.0083
# Epoch 9/30
# 256/256 [==============================] - 1463s 6s/step - loss: 5.2736 - accuracy: 0.0083 - val_loss: 5.2821 - val_accuracy: 0.0086
# Epoch 10/30
# 122/256 [=============>................] - ETA: 13:00 - loss: 5.2738 - accuracy: 0.0082
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-6c7a5cda86fd> in <module>
#       7     validation_data=validation_generator,
#       8     steps_per_epoch = steps_per_epoch,
# ----> 9     validation_steps = nb_validation_samples // batch_size)
#      10
#      11 cnn.save_weights('stanford_cars_folder_cnn_weights_OVERFITTED.h5')
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3725         input_length=None,
#    3726         time_major=False,
# -> 3727         zero_output_for_mask=False):
#    3728   """Iterates over the time dimension of a tensor.
#    3729
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1549   @property
#    1550   def is_method(self):
# -> 1551     return self._is_method
#    1552
#    1553   @property
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       ValueError: If a keyword in `kwargs` cannot be matched with a positional
#    1590         argument when an input signature is specified, or when the inputs
# -> 1591         do not conform to the input signature.
#    1592     """
#    1593     if self._input_signature is not None:
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690         input_signature,
#    1691         inputs[:len(input_signature)],
# -> 1692         expand_composites=True)
#    1693   except ValueError:
#    1694     raise ValueError("Structure of Python function inputs does not match "
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543       return outputs
#     544     else:
# --> 545       # TODO(b/128924522): This additional set_shape should not be
#     546       # necessary. ShapeRefiner likely needs to inspect handle_data. Remove this
#     547       # once that's done.
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
#Visualization of Validation and training set performance after overfitting
plt.figure(0, figsize = (5,5))
plt.plot(model_history.history['accuracy'],'orange')
plt.plot(model_history.history['val_accaccuracy'],'blue')
plt.legend(['Train-Accuracy','Val-Accuracy'])
_ = plt.title('Train vs Val Accuracy (OVERFITTED)')
_ = plt.xlabel('Epochs')
_ = plt.ylabel('Accuracy')

plt.figure(1, figsize = (5,5))
plt.plot(model_history.history['loss'],'orange')
plt.plot(model_history.history['val_loss'],'blue')
plt.legend(['train','validation'])
_ = plt.xlabel("Num of Epochs")
_ = plt.ylabel("Loss")
_ = plt.title("Training Loss vs Validation Loss (OVERFITTED)")
